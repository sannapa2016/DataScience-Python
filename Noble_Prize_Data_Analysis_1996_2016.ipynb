# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
df1 = pd.read_csv('archive.csv')

# %%
df1.head()
# Out:
#    Year    Category                                           Prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           Motivation Prize Share  Laureate ID  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   Laureate Type                     Full Name  Birth Date         Birth City  \
# ...

# %%
df1.dtypes
# Out:
# Year                    int64
# Category               object
# Prize                  object
# Motivation             object
# Prize Share            object
# Laureate ID             int64
# Laureate Type          object
# Full Name              object
# Birth Date             object
# Birth City             object
# Birth Nation           object
# Sex                    object
# Organization Name      object
# Organization City      object
# Organization Nation    object
# Death Date             object
# Death City             object
# Death Nation           object
# dtype: object

# %%
df1.shape
# Out:
# (969, 18)

# %%
df2 = df1.dropna()

# %%
df2.shape
# Out:
# (425, 18)

# %%
df3 = df2.sort_values(by='Birth Nation', ascending=True)

# %%
df3
# Out:
#      Year   Category                                              Prize  \
# 243  1947   Medicine     The Nobel Prize in Physiology or Medicine 1947
# 568  1984   Medicine     The Nobel Prize in Physiology or Medicine 1984
# 362  1963   Medicine     The Nobel Prize in Physiology or Medicine 1963
# 377  1964    Physics                    The Nobel Prize in Physics 1964
# 228  1945   Medicine     The Nobel Prize in Physiology or Medicine 1945
# ..    ...        ...                                                ...
# 482  1976  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 484  1976   Medicine     The Nobel Prize in Physiology or Medicine 1976
# 200  1937    Physics                    The Nobel Prize in Physics 1937
# 530  1980   Medicine     The Nobel Prize in Physiology or Medicine 1980
# 184  1935   Medicine     The Nobel Prize in Physiology or Medicine 1935
#
#                                             Motivation Prize Share  \
# ...

# %%
df3.head()
# Out:
#      Year  Category                                           Prize  \
# 243  1947  Medicine  The Nobel Prize in Physiology or Medicine 1947
# 568  1984  Medicine  The Nobel Prize in Physiology or Medicine 1984
# 362  1963  Medicine  The Nobel Prize in Physiology or Medicine 1963
# 377  1964   Physics                 The Nobel Prize in Physics 1964
# 228  1945  Medicine  The Nobel Prize in Physiology or Medicine 1945
#
#                                             Motivation Prize Share  \
# 243  "for his discovery of the part played by the h...         1/2
# 568  "for theories concerning the specificity in de...         1/3
# 362  "for their discoveries concerning the ionic me...         1/3
# 377  "for fundamental work in the field of quantum ...         1/4
# 228  "for the discovery of penicillin and its curat...         1/3
#
#      Laureate ID Laureate Type                         Full Name  Birth Date  \
# ...

# %%
df4 = df3.iloc[:, [0,1,10,11,12,14]]

# %%
df4.head()
# Out:
#      Year  Category Birth Nation   Sex  \
# 243  1947  Medicine    Argentina  Male
# 568  1984  Medicine    Argentina  Male
# 362  1963  Medicine    Australia  Male
# 377  1964   Physics    Australia  Male
# 228  1945  Medicine    Australia  Male
#
#                                      Organization Name  \
# 243  Instituto de Biologia y Medicina Experimental ...
# 568                MRC Laboratory of Molecular Biology
# 362                     Australian National University
# 377                    P.N. Lebedev Physical Institute
# 228                               University of Oxford
#
#                      Organization Nation
# 243                            Argentina
# 568                       United Kingdom
# 362                            Australia
# 377  Union of Soviet Socialist Republics
# 228                       United Kingdom

# %%
df5 = df4.loc[df4['Organization Nation'] == 'United States of America']

# %%
df5
# Out:
#      Year   Category                      Birth Nation     Sex  \
# 230  1945    Physics                           Austria    Male
# 711  1998  Chemistry                           Austria    Male
# 242  1947   Medicine  Austria-Hungary (Czech Republic)  Female
# 241  1947   Medicine  Austria-Hungary (Czech Republic)    Male
# 367  1963    Physics         Austria-Hungary (Hungary)    Male
# ..    ...        ...                               ...     ...
# 481  1976  Chemistry          United States of America    Male
# 482  1976  Economics          United States of America    Male
# 484  1976   Medicine          United States of America    Male
# 200  1937    Physics          United States of America    Male
# 530  1980   Medicine                         Venezuela    Male
#
#                      Organization Name       Organization Nation
# 230               Princeton University  United States of America
# 711           University of California  United States of America
# ...

# %%
 df5.reset_index(drop = True)
# Out:
#      Year   Category                      Birth Nation     Sex  \
# 0    1945    Physics                           Austria    Male
# 1    1998  Chemistry                           Austria    Male
# 2    1947   Medicine  Austria-Hungary (Czech Republic)  Female
# 3    1947   Medicine  Austria-Hungary (Czech Republic)    Male
# 4    1963    Physics         Austria-Hungary (Hungary)    Male
# ..    ...        ...                               ...     ...
# 177  1976  Chemistry          United States of America    Male
# 178  1976  Economics          United States of America    Male
# 179  1976   Medicine          United States of America    Male
# 180  1937    Physics          United States of America    Male
# 181  1980   Medicine                         Venezuela    Male
#
#                      Organization Name       Organization Nation
# 0                 Princeton University  United States of America
# 1             University of California  United States of America
# ...

# %%
df6 = df4.loc[df4['Organization Nation'] == 'United Kingdom']
df6
# Out:
#      Year   Category    Birth Nation   Sex  \
# 568  1984   Medicine       Argentina  Male
# 228  1945   Medicine       Australia  Male
# 86   1915    Physics       Australia  Male
# 351  1962  Chemistry         Austria  Male
# 341  1960   Medicine          Brazil  Male
# ..    ...        ...             ...   ...
# 304  1956  Chemistry  United Kingdom  Male
# 85   1915    Physics  United Kingdom  Male
# 352  1962  Chemistry  United Kingdom  Male
# 408  1969  Chemistry  United Kingdom  Male
# 364  1963   Medicine  United Kingdom  Male
#
#                        Organization Name Organization Nation
# 568  MRC Laboratory of Molecular Biology      United Kingdom
# 228                 University of Oxford      United Kingdom
# 86                   Victoria University      United Kingdom
# 351  MRC Laboratory of Molecular Biology      United Kingdom
# 341                   University College      United Kingdom
# ..                                   ...                 ...
# ...

# %%
df6.reset_index(drop = True)
# Out:
#     Year   Category    Birth Nation   Sex  \
# 0   1984   Medicine       Argentina  Male
# 1   1945   Medicine       Australia  Male
# 2   1915    Physics       Australia  Male
# 3   1962  Chemistry         Austria  Male
# 4   1960   Medicine          Brazil  Male
# ..   ...        ...             ...   ...
# 61  1956  Chemistry  United Kingdom  Male
# 62  1915    Physics  United Kingdom  Male
# 63  1962  Chemistry  United Kingdom  Male
# 64  1969  Chemistry  United Kingdom  Male
# 65  1963   Medicine  United Kingdom  Male
#
#                       Organization Name Organization Nation
# 0   MRC Laboratory of Molecular Biology      United Kingdom
# 1                  University of Oxford      United Kingdom
# 2                   Victoria University      United Kingdom
# 3   MRC Laboratory of Molecular Biology      United Kingdom
# 4                    University College      United Kingdom
# ..                                  ...                 ...
# ...

# %%
df7 = df4.loc[df4['Organization Nation'] == 'Germany']

# %%
df7.reset_index(drop = True)
# Out:
#     Year   Category                Birth Nation   Sex  \
# 0   1933    Physics                     Austria  Male
# 1   1938  Chemistry   Austria-Hungary (Austria)  Male
# 2   1938  Chemistry   Austria-Hungary (Austria)  Male
# 3   1925  Chemistry   Austrian Empire (Austria)  Male
# 4   1907  Chemistry           Bavaria (Germany)  Male
# 5   1931   Medicine                     Germany  Male
# 6   1944  Chemistry                     Germany  Male
# 7   1939  Chemistry                     Germany  Male
# 8   1939  Chemistry                     Germany  Male
# 9   1932    Physics                     Germany  Male
# 10  1931  Chemistry                     Germany  Male
# 11  1905   Medicine                     Germany  Male
# 12  1914    Physics                     Germany  Male
# 13  1915  Chemistry                     Germany  Male
# 14  1931  Chemistry                     Germany  Male
# 15  1919    Physics                     Germany  Male
# ...

# %%
pd.value_counts(df1.values.flatten())
# Out:
# Individual                                                                                         939
# Male                                                                                               893
# United States of America                                                                           849
# 1/1                                                                                                351
# 1/2                                                                                                328
#                                                                                                   ...
# 548                                                                                                  1
# The Sveriges Riksbank Prize in Economic Sciences 1973                                                1
# Mother Teresa                                                                                        1
# ...

# %%
sns.swarmplot(x=df3['Sex'],
              y=df3['Year'])
