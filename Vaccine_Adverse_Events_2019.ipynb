# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')

# %%
#reading vaccine adverse events data 
df1 = pd.read_csv('2019VAERSData.csv', encoding = 'latin-1')

#reading the profile of the dataframe
#pandas_profiling.ProfileReport(df1)

#reading vaccine info data
df2 = pd.read_csv('2019VAERSVAX.csv', encoding = 'latin-1')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=24222, step=1)

# %%
df1.shape
# Out:
# (24222, 35)

# %%
df1.dtypes
# Out:
# VAERS_ID          int64
# RECVDATE         object
# STATE            object
# AGE_YRS         float64
# CAGE_YR         float64
# CAGE_MO         float64
# SEX              object
# RPT_DATE         object
# SYMPTOM_TEXT     object
# DIED             object
# DATEDIED         object
# L_THREAT         object
# ER_VISIT         object
# HOSPITAL         object
# HOSPDAYS        float64
# X_STAY           object
# DISABLE          object
# RECOVD           object
# VAX_DATE         object
# ONSET_DATE       object
# NUMDAYS         float64
# LAB_DATA         object
# V_ADMINBY        object
# V_FUNDBY         object
# OTHER_MEDS       object
# CUR_ILL          object
# HISTORY          object
# PRIOR_VAX        object
# SPLTTYPE         object
# FORM_VERS         int64
# TODAYS_DATE      object
# BIRTH_DEFECT     object
# OFC_VISIT        object
# ER_ED_VISIT      object
# ALLERGIES        object
# dtype: object

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=30838, step=1)

# %%
df2.shape
# Out:
# (30838, 8)

# %%
df2.dtypes
# Out:
# VAERS_ID            int64
# VAX_TYPE           object
# VAX_MANU           object
# VAX_LOT            object
# VAX_DOSE_SERIES    object
# VAX_ROUTE          object
# VAX_SITE           object
# VAX_NAME           object
# dtype: object

# %%
df1.isnull().sum()
# Out:
# VAERS_ID            0
# RECVDATE            0
# STATE            7815
# AGE_YRS          6274
# CAGE_YR          7198
# CAGE_MO         22103
# SEX                 0
# RPT_DATE        22939
# SYMPTOM_TEXT        2
# DIED            24092
# DATEDIED        24162
# L_THREAT        24039
# ER_VISIT        24049
# HOSPITAL        23175
# HOSPDAYS        23722
# X_STAY          24204
# DISABLE         23655
# RECOVD           1357
# VAX_DATE         3640
# ONSET_DATE       5327
# NUMDAYS          6039
# LAB_DATA        16902
# V_ADMINBY           0
# V_FUNDBY        22903
# OTHER_MEDS      12079
# CUR_ILL         13302
# HISTORY         13444
# PRIOR_VAX       23073
# SPLTTYPE        13919
# FORM_VERS           0
# TODAYS_DATE      1413
# BIRTH_DEFECT    24209
# OFC_VISIT       18157
# ER_ED_VISIT     22188
# ALLERGIES       13754
# dtype: int64

# %%
df1.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    794156  01/01/2019   NaN     69.0     69.0      NaN   F      NaN
# 1    794157  01/01/2019    IL     68.0     68.0      NaN   F      NaN
# 2    794158  01/01/2019    MA     62.0     62.0      NaN   F      NaN
# 3    794159  01/01/2019    UT      5.0      5.0      NaN   M      NaN
# 4    794160  01/01/2019    TX     79.0     79.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Severe pain Lt. shoulder area, very localized ...  NaN  ...
# 1  Much joint pain/aching, lack of energy, listle...  NaN  ...
# 2  Headache, Fever, Chills, Body Aches, Nausea la...  NaN  ...
# 3  Site is swollen, red and warm to the touch. Pa...  NaN  ...
# 4  FLU LIKE: CHILLS ACHE ALL OVER; STRONG PAIN, W...  NaN  ...
#
#                                              CUR_ILL                HISTORY  \
# 0                                               none                   none
# ...

# %%
df3 = df1.iloc[:, [0, 3, 6,13,14,15,16,17,31,34]] #keeping required columns from df1

# %%
df3.head()
# Out:
#    VAERS_ID  AGE_YRS SEX HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD  \
# 0    794156     69.0   F      NaN       NaN    NaN     NaN      Y
# 1    794157     68.0   F      NaN       NaN    NaN     NaN      N
# 2    794158     62.0   F      NaN       NaN    NaN     NaN      Y
# 3    794159      5.0   M      NaN       NaN    NaN     NaN      Y
# 4    794160     79.0   F      NaN       NaN    NaN     NaN      N
#
#   BIRTH_DEFECT       ALLERGIES
# 0          NaN    tetracycline
# 1          NaN            None
# 2          NaN            None
# 3          NaN     Amoxicillin
# 4          NaN  ACE INHIBITORS

# %%
df2.head()
# Out:
#    VAERS_ID VAX_TYPE                     VAX_MANU  VAX_LOT VAX_DOSE_SERIES  \
# 0    794156     FLU4  GLAXOSMITHKLINE BIOLOGICALS    JZ3B7             UNK
# 1    794157   VARZOS  GLAXOSMITHKLINE BIOLOGICALS      NaN             UNK
# 2    794158   VARZOS  GLAXOSMITHKLINE BIOLOGICALS      NaN             UNK
# 3    794159  DTAPIPV  GLAXOSMITHKLINE BIOLOGICALS    G9P35               1
# 4    794159     MMRV             MERCK & CO. INC.  R015744               1
#
#   VAX_ROUTE VAX_SITE                                         VAX_NAME
# 0        IM       LA      INFLUENZA (SEASONAL) (FLUARIX QUADRIVALENT)
# 1       NaN      NaN                                ZOSTER (SHINGRIX)
# 2       NaN      NaN                                ZOSTER (SHINGRIX)
# 3        IM       LL                              DTAP + IPV (KINRIX)
# 4        SC       LL  MEASLES + MUMPS + RUBELLA + VARICELLA (PROQUAD)

# %%
df4 = df2.iloc[:, [0, 1, 2,5,6,7]] #keeping required columns from df2

# %%
df4.head()
# Out:
#    VAERS_ID VAX_TYPE                     VAX_MANU VAX_ROUTE VAX_SITE  \
# 0    794156     FLU4  GLAXOSMITHKLINE BIOLOGICALS        IM       LA
# 1    794157   VARZOS  GLAXOSMITHKLINE BIOLOGICALS       NaN      NaN
# 2    794158   VARZOS  GLAXOSMITHKLINE BIOLOGICALS       NaN      NaN
# 3    794159  DTAPIPV  GLAXOSMITHKLINE BIOLOGICALS        IM       LL
# 4    794159     MMRV             MERCK & CO. INC.        SC       LL
#
#                                           VAX_NAME
# 0      INFLUENZA (SEASONAL) (FLUARIX QUADRIVALENT)
# 1                                ZOSTER (SHINGRIX)
# 2                                ZOSTER (SHINGRIX)
# 3                              DTAP + IPV (KINRIX)
# 4  MEASLES + MUMPS + RUBELLA + VARICELLA (PROQUAD)

# %%
df3.sort_values(by=['VAERS_ID'])
df3.head()
# Out:
#    VAERS_ID  AGE_YRS SEX HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD  \
# 0    794156     69.0   F      NaN       NaN    NaN     NaN      Y
# 1    794157     68.0   F      NaN       NaN    NaN     NaN      N
# 2    794158     62.0   F      NaN       NaN    NaN     NaN      Y
# 3    794159      5.0   M      NaN       NaN    NaN     NaN      Y
# 4    794160     79.0   F      NaN       NaN    NaN     NaN      N
#
#   BIRTH_DEFECT       ALLERGIES
# 0          NaN    tetracycline
# 1          NaN            None
# 2          NaN            None
# 3          NaN     Amoxicillin
# 4          NaN  ACE INHIBITORS

# %%
df4.sort_values(by=['VAERS_ID'])
df4.head()
# Out:
#    VAERS_ID VAX_TYPE                     VAX_MANU VAX_ROUTE VAX_SITE  \
# 0    794156     FLU4  GLAXOSMITHKLINE BIOLOGICALS        IM       LA
# 1    794157   VARZOS  GLAXOSMITHKLINE BIOLOGICALS       NaN      NaN
# 2    794158   VARZOS  GLAXOSMITHKLINE BIOLOGICALS       NaN      NaN
# 3    794159  DTAPIPV  GLAXOSMITHKLINE BIOLOGICALS        IM       LL
# 4    794159     MMRV             MERCK & CO. INC.        SC       LL
#
#                                           VAX_NAME
# 0      INFLUENZA (SEASONAL) (FLUARIX QUADRIVALENT)
# 1                                ZOSTER (SHINGRIX)
# 2                                ZOSTER (SHINGRIX)
# 3                              DTAP + IPV (KINRIX)
# 4  MEASLES + MUMPS + RUBELLA + VARICELLA (PROQUAD)

# %%
df5 = pd.concat([df3,df4], axis =1) #combining adverse events and vaccine info datasets
df5.head()
# Out:
#    VAERS_ID  AGE_YRS SEX HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD  \
# 0  794156.0     69.0   F      NaN       NaN    NaN     NaN      Y
# 1  794157.0     68.0   F      NaN       NaN    NaN     NaN      N
# 2  794158.0     62.0   F      NaN       NaN    NaN     NaN      Y
# 3  794159.0      5.0   M      NaN       NaN    NaN     NaN      Y
# 4  794160.0     79.0   F      NaN       NaN    NaN     NaN      N
#
#   BIRTH_DEFECT       ALLERGIES  VAERS_ID VAX_TYPE  \
# 0          NaN    tetracycline    794156     FLU4
# 1          NaN            None    794157   VARZOS
# 2          NaN            None    794158   VARZOS
# 3          NaN     Amoxicillin    794159  DTAPIPV
# 4          NaN  ACE INHIBITORS    794159     MMRV
#
#                       VAX_MANU VAX_ROUTE VAX_SITE  \
# 0  GLAXOSMITHKLINE BIOLOGICALS        IM       LA
# 1  GLAXOSMITHKLINE BIOLOGICALS       NaN      NaN
# 2  GLAXOSMITHKLINE BIOLOGICALS       NaN      NaN
# 3  GLAXOSMITHKLINE BIOLOGICALS        IM       LL
# ...

# %%
df5.dtypes
# Out:
# VAERS_ID        float64
# AGE_YRS         float64
# SEX              object
# HOSPITAL         object
# HOSPDAYS        float64
# X_STAY           object
# DISABLE          object
# RECOVD           object
# BIRTH_DEFECT     object
# ALLERGIES        object
# VAERS_ID          int64
# VAX_TYPE         object
# VAX_MANU         object
# VAX_ROUTE        object
# VAX_SITE         object
# VAX_NAME         object
# dtype: object

# %%
df6 = df5.loc[df5['HOSPITAL'] == 'Y'] # identifying the hosptalized population data because of the adverse events

# %%
df6.head()
# Out:
#     VAERS_ID  AGE_YRS SEX HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD  \
# 25  794190.0      NaN   F        Y       NaN    NaN     NaN      N
# 26  794191.0      NaN   M        Y       NaN    NaN     NaN      N
# 30  794195.0     4.00   M        Y       NaN    NaN     NaN      Y
# 45  794217.0     0.33   M        Y       6.0    NaN     NaN      N
# 63  794268.0     1.00   M        Y       2.0    NaN     NaN      Y
#
#    BIRTH_DEFECT ALLERGIES  VAERS_ID VAX_TYPE                     VAX_MANU  \
# 25          NaN       NaN    794178     FLU4                SEQIRUS, INC.
# 26          NaN       NaN    794178     JEV1                 INTERCELL AG
# 30          NaN       NaN    794181   VARZOS  GLAXOSMITHKLINE BIOLOGICALS
# 45          NaN      none    794205     MMRV             MERCK & CO. INC.
# 63          NaN      None    794226   VARZOS  GLAXOSMITHKLINE BIOLOGICALS
#
#    VAX_ROUTE VAX_SITE                                         VAX_NAME
# ...

# %%
df7 = df6.loc[df6['HOSPDAYS'] >= 1.0]
df7.head()
# Out:
#      VAERS_ID  AGE_YRS SEX HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD  \
# 45   794217.0     0.33   M        Y       6.0    NaN     NaN      N
# 63   794268.0     1.00   M        Y       2.0    NaN     NaN      Y
# 98   794330.0     1.00   M        Y       2.0    NaN     NaN      Y
# 114  794350.0     0.33   F        Y       2.0    NaN     NaN      Y
# 187  794472.0    84.00   M        Y       4.0    NaN       Y      N
#
#     BIRTH_DEFECT ALLERGIES  VAERS_ID VAX_TYPE                     VAX_MANU  \
# 45           NaN      none    794205     MMRV             MERCK & CO. INC.
# 63           NaN      None    794226   VARZOS  GLAXOSMITHKLINE BIOLOGICALS
# 98           NaN      None    794291   VARZOS             MERCK & CO. INC.
# 114          NaN      none    794306   VARZOS  GLAXOSMITHKLINE BIOLOGICALS
# 187          NaN       NaN    794383   VARCEL         UNKNOWN MANUFACTURER
#
#     VAX_ROUTE VAX_SITE                                         VAX_NAME
# ...

# %%
df8 = df7.loc[df7['DISABLE'] == 'Y']
df8.head()
# Out:
#      VAERS_ID  AGE_YRS SEX HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD  \
# 187  794472.0    84.00   M        Y       4.0    NaN       Y      N
# 392  794722.0    56.00   M        Y      15.0    NaN       Y      N
# 444  794773.0    17.00   M        Y       2.0    NaN       Y      N
# 725  795231.0    20.00   F        Y       7.0    NaN       Y      N
# 732  795198.0     0.08   M        Y       4.0    NaN       Y      Y
#
#     BIRTH_DEFECT                                    ALLERGIES  VAERS_ID  \
# 187          NaN                                          NaN    794383
# 392          NaN                           no known allergies    794621
# 444          NaN                                  Sulfa drugs    794680
# 725          NaN  Citrus; ZANTAC; MS04; CDN; Fentanyl; MOTRIN    794972
# 732          NaN                         Peanuts, amoxicillin    794979
#
#        VAX_TYPE                     VAX_MANU VAX_ROUTE VAX_SITE  \
# ...

# %%
df9 = df8.loc[df8['BIRTH_DEFECT'] == 'Y']
df9
# Out:
#        VAERS_ID  AGE_YRS SEX HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD  \
# 2092   796987.0      0.0   F        Y       3.0    NaN       Y      N
# 3158   798525.0      NaN   U        Y       7.0    NaN       Y      N
# 4729   800887.0      0.0   F        Y       3.0    NaN       Y      N
# 11504  809199.0      0.0   M        Y       7.0    NaN       Y    NaN
#
#       BIRTH_DEFECT                                          ALLERGIES  \
# 2092             Y                                                NaN
# 3158             Y                                                NaN
# 4729             Y  None. However pt has shown extreme reactions t...
# 11504            Y                                               None
#
#        VAERS_ID VAX_TYPE                     VAX_MANU VAX_ROUTE VAX_SITE  \
# 2092     796361     DTAP               SANOFI PASTEUR        IM       LL
# 3158     798154      MNQ               SANOFI PASTEUR        IM       RA
# ...

# %%
df10 = df8.loc[df8['VAX_TYPE'] == 'VARCEL']
df10
# Out:
#       VAERS_ID  AGE_YRS SEX HOSPITAL  HOSPDAYS X_STAY DISABLE RECOVD  \
# 187   794472.0     84.0   M        Y       4.0    NaN       Y      N
# 836   795334.0     56.0   M        Y       2.0    NaN       Y      N
# 5126  801394.0      3.0   M        Y       5.0    NaN       Y      N
# 8191  805166.0     61.0   M        Y      14.0    NaN       Y      N
#
#      BIRTH_DEFECT                         ALLERGIES  VAERS_ID VAX_TYPE  \
# 187           NaN                               NaN    794383   VARCEL
# 836           NaN  Penicillin / Codeine / Shellfish    795121   VARCEL
# 5126          NaN         Milk allergy lactose free    800058   VARCEL
# 8191          NaN                              None    802948   VARCEL
#
#                   VAX_MANU VAX_ROUTE VAX_SITE                   VAX_NAME
# 187   UNKNOWN MANUFACTURER        UN       UN  VARICELLA (NO BRAND NAME)
# 836   UNKNOWN MANUFACTURER       NaN      NaN  VARICELLA (NO BRAND NAME)
# ...
